# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns


rng = np.random.RandomState(0)
x= np.linspace(0,10,500)
y= np.cumsum(rng.randn(500,6), 0)

# %%
sns.set()
plt.plot(x,y)
plt.legend('ABCDEF',ncol=3, loc='lower center');

# %%
data = np.random.multivariate_normal([0,0],[[5,2],[2,2]], size = 2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], density=True, alpha=0.5, label=["rect1", "rect2"]);
    plt.legend();

# %%
data = np.random.multivariate_normal([0,0],[[5,2],[2,2]], size = 2000)
data = pd.DataFrame(data, columns=['x', 'y'])
color = ['r','k']


plt.hist(data['x'], density=True, alpha=0.5, color='r', label="rect 1");
plt.hist(data['y'], density=True, alpha=0.5, color='k', label="rect 2");
plt.legend();

# %%
for col in 'xy':
    sns.kdeplot(data[col],shade=True)

# %%
sns.distplot(data['x'])
sns.distplot(data['y']);

# %%
sns.kdeplot(data, color="r");
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("x","y",data,kind="scatter", color="red")

# %%
with sns.axes_style('white'):
    sns.jointplot("x","y",data,kind="kde", color="red")

# %%
with sns.axes_style('white'):
    sns.jointplot("x","y",data,kind="hex", color="red")

# %%
iris2 = sns.load_dataset("iris")
iris2.head()

# %%
iris2.shape
# Out:
# (150, 5)

# %%
iris3 = pd.DataFrame(iris2)
iris2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris3 = df.drop(columns='species')
iris3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris3.columns = ["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"]

# %%
iris3.rename(columns={'sepal_length':'sepal length (cm)','sepal_width':'sepal width (cm)','petal_length':'petal length (cm)', 'petal_width':'petal width (cm)'}, 
                 inplace=True)

# %%
iris3
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.datasets import load_iris
iris = load_iris();
data1 = pd.DataFrame(data= np.c_[iris['data']],
                     columns= iris['feature_names'])

# %%
data1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris3.equals(data1)
# Out:
# True

# %%
iris = load_iris();
data2 = pd.DataFrame(data= np.c_[iris['data']],
                     columns= iris['feature_names'])
